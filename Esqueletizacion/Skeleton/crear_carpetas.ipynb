# %%
paths = [
    "./Data/results/ATM_"+f'{i:03d}_0000 segmentation' for i in range(1, 31)

    ] 

paths
# Out:
# ['./Data/results/ATM_001_0000 segmentation',
#  './Data/results/ATM_002_0000 segmentation',
#  './Data/results/ATM_003_0000 segmentation',
#  './Data/results/ATM_004_0000 segmentation',
#  './Data/results/ATM_005_0000 segmentation',
#  './Data/results/ATM_006_0000 segmentation',
#  './Data/results/ATM_007_0000 segmentation',
#  './Data/results/ATM_008_0000 segmentation',
#  './Data/results/ATM_009_0000 segmentation',
#  './Data/results/ATM_010_0000 segmentation',
#  './Data/results/ATM_011_0000 segmentation',
#  './Data/results/ATM_012_0000 segmentation',
#  './Data/results/ATM_013_0000 segmentation',
#  './Data/results/ATM_014_0000 segmentation',
#  './Data/results/ATM_015_0000 segmentation',
#  './Data/results/ATM_016_0000 segmentation',
#  './Data/results/ATM_017_0000 segmentation',
#  './Data/results/ATM_018_0000 segmentation',
#  './Data/results/ATM_019_0000 segmentation',
#  './Data/results/ATM_020_0000 segmentation',
#  './Data/results/ATM_021_0000 segmentation',
# ...

# %% [markdown]
# Este es una celda que crea carpetas con el mismo nombre de las mascaras de las vias aereas. Debes correrlo una vez solamente en la carpeta donde tengas la data. Esto es para que al correr el codigo de Main_skeleton_calc_dataset.py guarde todos los archivos que genera en la carpeta correspondiente de la mascara.

# %%
# import os
# import shutil

# # Lista de archivos con extensión
# paths = [
#     f"./Data/results/ATM_{i:03d}_0000 segmentation.nii.gz"
#     for i in range(1, 31)
# ]

# for file_path in paths:
#     if not os.path.exists(file_path):
#         print(f"[!] Archivo no encontrado: {file_path}")
#         continue

#     # Nombre base sin la extensión .nii.gz
#     file_name = os.path.basename(file_path)
#     folder_name = file_name.replace(".nii.gz", "")
#     folder_path = os.path.join(os.path.dirname(file_path), folder_name)

#     # Crear la carpeta si no existe
#     os.makedirs(folder_path, exist_ok=True)

#     # Nuevo path para mover el archivo
#     new_file_path = os.path.join(folder_path, file_name)
#     shutil.move(file_path, new_file_path)

#     print(f"[✔] Movido: {file_path} → {new_file_path}")
# Out:
# [✔] Movido: ./Data/results/ATM_001_0000 segmentation.nii.gz → ./Data/results/ATM_001_0000 segmentation/ATM_001_0000 segmentation.nii.gz
# [✔] Movido: ./Data/results/ATM_002_0000 segmentation.nii.gz → ./Data/results/ATM_002_0000 segmentation/ATM_002_0000 segmentation.nii.gz
# [✔] Movido: ./Data/results/ATM_003_0000 segmentation.nii.gz → ./Data/results/ATM_003_0000 segmentation/ATM_003_0000 segmentation.nii.gz
# [✔] Movido: ./Data/results/ATM_004_0000 segmentation.nii.gz → ./Data/results/ATM_004_0000 segmentation/ATM_004_0000 segmentation.nii.gz
# [✔] Movido: ./Data/results/ATM_005_0000 segmentation.nii.gz → ./Data/results/ATM_005_0000 segmentation/ATM_005_0000 segmentation.nii.gz
# [✔] Movido: ./Data/results/ATM_006_0000 segmentation.nii.gz → ./Data/results/ATM_006_0000 segmentation/ATM_006_0000 segmentation.nii.gz
# [✔] Movido: ./Data/results/ATM_007_0000 segmentation.nii.gz → ./Data/results/ATM_007_0000 segmentation/ATM_007_0000 segmentation.nii.gz
# ...

# %%
k =[ "./Data/results/ATM_"+f'{i:03d}_0000 segmentation/ATM_'+f'{i:03d}_0000 segmentation' for i in range(1, 31)]
k[0]

if not os.path.exists(k[0]+".nii.gz"):
    print(f"[!] Archivo no encontrado: {k[0]}")
else:
    print("bacano")
# Out:
# bacano
